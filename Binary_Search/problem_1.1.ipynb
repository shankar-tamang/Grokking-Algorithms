# %% [markdown]
# ## Problem 1.1
# Q.1.1 Suppose you have a sorted list of 128 names, and you are searching thorugh it using binary serach. What's the
# maximum number of steps it would take?
#
# Ans. A binary search takes logn for worst possible case so log(128) would be 7, so in seven steps

# %%
# !pip install faker

# %%
from faker import Faker

fake = Faker()

names = sorted({fake.name() for _ in range(300)})

names_128 = names[:128]

for name in names_128:
    print(name)
# Out:
# Alexander Chambers
# Alexis Brown
# Alicia Hall
# Alicia Nguyen
# Allison Campbell
# Amanda Hardy
# Amber Flores
# Amber Johnson
# Amy Cooke
# Amy Jones
# Andrea Small
# Andrew Schmitt
# Angel Smith
# Angela Dennis MD
# Anita Mack
# Anna Parks
# Anthony Soto
# April Baxter
# April Gray
# Ashley Jones
# Ashley Roberts
# Austin Jordan
# Bernard Williams
# Beth Myers
# Beverly Johnson
# Bonnie Douglas
# Brandon Carney
# Brandon Harvey
# Brandon Mcintyre
# Brian Green
# Brian Perez
# Brian Perkins
# Brianna Porter
# Brittany Brown
# Carla Williams
# Carolyn Morse
# Carolyn Smith
# Charlene Jefferson
# Charles Martinez
# Cheryl Gonzalez
# Christian Rose
# Christian Ross
# Christine Rivera
# Christopher Baker
# Christopher Bush
# Christopher Fowler
# Christopher Hill
# Christopher Martin
# Christopher Miller
# Christopher Parker MD
# Christopher Rogers
# Christopher Snyder
# Christopher Young
# Christy Cross
# Christy Sweeney
# Claire Ray
# Cristian Cunningham
# Crystal King
# Cynthia Cox
# Dale Hunter
# Dana Lopez
# Daniel Boyd
# Daniel Moore
# Daniel Thomas
# Danielle Merritt
# Danielle Ross
# Darrell Novak
# Darryl Anderson
# David Wang
# David Williams
# Dawn Jordan
# Deanna Krueger
# Deborah Little
# Debra Coleman
# Debra Gill
# Debra Gonzalez
# Dennis Powell
# Derek Moreno
# Derrick Garza
# Desiree Johnson
# Diane Page
# Donna Jones
# Douglas Ferrell
# Dr. James Flores
# Dr. Jennifer Obrien
# Dustin Smith
# Edward Fletcher
# Edward Robinson
# Edwin Taylor
# Emily Bell
# Eric Watson
# Erin Ortiz
# Erin Ross
# Frank Webb
# Frederick Hart
# Gary Nelson
# Gary Rios
# George Meyers
# George Tran
# Gina Matthews
# Grace Hill
# Gregory Ware
# Hayley Nielsen
# Heather Hood
# Helen Schaefer
# Henry Matthews
# Henry Mccormick
# Hunter Adams
# Ian Anderson
# Ian Harris
# Isaac Armstrong
# Jackson Graves
# Jacob Carter
# Jacob Hernandez
# Jake Adams
# James Quinn
# Janet Miller
# Jason Cross
# Jason Nolan
# Jason Stewart
# Jeffery Evans
# Jeffrey Baker
# Jeffrey Hamilton
# Jennifer Carpenter
# Jennifer Martinez
# Jennifer Mullen
# Jennifer Shannon
# Jennifer Vega

# %%
last_name = names_128[-1]
print(last_name)
# Out:
# Jennifer Vega

# %%
def binary_search(num_list, item):
    low = 0
    high = len(num_list) - 1
    steps = 0

    while low <= high:

        steps += 1
        mid = round((low + high) / 2)
        guess = num_list[mid]

        if guess == item:
            return mid, steps
        
        elif guess > item:
            high = mid - 1

        else:
            low = mid + 1

    return None

# %%
binary_search(names_128, 'Jennifer Vega')
# Out:
# (127, 7)

# %% [markdown]
# ## Problem 1.2
# Q.1.2.Suppose you double the size of list. What's the maximum number of steps now.
#
# Ans. If we double the size it will be the size will be 256 and log(256), which is 8, so the maximum number of steps is 8.

# %%
names = sorted({fake.name() for _ in range(600)})
names_256 = names[:256]

# %%
names_256[-1]
# Out:
# 'Jeremy George'

# %%
binary_search(names_256, 'Jeremy George')
# Out:
# (255, 8)
